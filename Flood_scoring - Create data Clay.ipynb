# %% [markdown]
# # Importing libraries

# %%
import time
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, box
from collections import defaultdict

import os
os.chdir(r"E:\Data challenge")

# %% [markdown]
# # Importing data

# %%
print("Loading clay data...")
data_clay = gpd.read_file(r"data\sol_argileux\ExpoArgile_Fxx_L93.shp")
data_clay = data_clay[['geometry', 'ALEA', 'NIVEAU']]

print(f"Clay data loaded: {len(data_clay)} features")
print(f"CRS: {data_clay.crs}")
# Out:
# Loading clay data...
# Clay data loaded: 122222 features
# CRS: EPSG:2154

# %%
data_drias = pd.read_csv(r"data\Drias_data\RCP_4.5.csv", sep=";", header=31)

# %% [markdown]
# # Create points

# %%
# Create points
print("\nCreating point geometries...")
points_gdf = gpd.GeoDataFrame(
    data_drias,
    geometry=[Point(lon, lat) for lon, lat in zip(data_drias['Longitude'], data_drias['Latitude'])],
    crs='EPSG:4326'  # Points are in WGS84
)

print(f"Points created: {len(points_gdf)}")
# Out:
# Creating point geometries...
# Points created: 26943

# %% [markdown]
# # Filter points that doesn't belong to metropolitan France

# %%
# Transform points to match clay data CRS
print(f"\nTransforming points from EPSG:4326 to {data_clay.crs}...")
points_gdf = points_gdf.to_crs(data_clay.crs)

# Filter clay data to region of interest
print("\nFiltering clay data to points region...")
point_bounds = points_gdf.total_bounds
buffer_margin = 1000  # meters (since L93 is in meters)

min_x = point_bounds[0] - buffer_margin
min_y = point_bounds[1] - buffer_margin
max_x = point_bounds[2] + buffer_margin
max_y = point_bounds[3] + buffer_margin

data_clay = data_clay.cx[min_x:max_x, min_y:max_y]

print(f"Filtered clay data: {len(data_clay)} features")
# Out:
# Transforming points from EPSG:4326 to EPSG:2154...
#
# Filtering clay data to points region...
# Filtered clay data: 122216 features

# %% [markdown]
# # Create spatial index and create radius for buffer

# %%
# Create spatial index
print("Creating spatial index...")
sindex = data_clay.sindex
print("Spatial index created!")
# Out:
# Creating spatial index...
# Spatial index created!

# %% [markdown]
# # Join drias and flood dataframe spatially

# %%
# Buffer distance in meters (L93 uses meters)
buffer_distance = 1  # 10 meters

# Process points
results = []
start_time = time.time()
print(f"\nProcessing {len(points_gdf)} points with buffer_distance={buffer_distance}m...")

for idx_num, (idx, point_row) in enumerate(points_gdf.iterrows()):
    
    # Progress update every 100 points
    if idx_num % 100 == 0:
        elapsed = time.time() - start_time
        if idx_num > 0:
            rate = idx_num / elapsed
            remaining = len(points_gdf) - idx_num
            est_remaining = remaining / rate / 60
            
            print(f"Point {idx_num}/{len(points_gdf)} ({idx_num/len(points_gdf)*100:.1f}%) | "
                  f"Rate: {rate:.2f} pts/sec | Elapsed: {elapsed:.1f}s | "
                  f"Est. remaining: {est_remaining:.1f}min")
    
    point = point_row.geometry
    lon = data_drias.loc[idx, 'Longitude']
    lat = data_drias.loc[idx, 'Latitude']
    
    # Create bounding box
    x, y = point.x, point.y
    bbox = box(x - buffer_distance, y - buffer_distance, 
               x + buffer_distance, y + buffer_distance)
    
    # Query spatial index
    possible_matches_idx = list(sindex.query(bbox))
    
    # Debug first point
    if idx_num == 0:
        print(f"\nFirst point found {len(possible_matches_idx)} candidates")
    
    if not possible_matches_idx:
        results.append({
            'longitude': lon,
            'latitude': lat,
            'alea': None,
            'niveau': None
        })
        continue
    
    # Get candidates
    possible_matches = data_clay.iloc[possible_matches_idx]
    
    # Collect all matching ALEA and NIVEAU values
    alea_list = []
    niveau_list = []
    
    for _, clay_row in possible_matches.iterrows():
        if point.distance(clay_row.geometry) <= buffer_distance:
            alea_list.append(clay_row['ALEA'])
            niveau_list.append(clay_row['NIVEAU'])
    
    results.append({
        'longitude': lon,
        'latitude': lat,
        'alea': max(set(alea_list), key=alea_list.count, default=None),
        'niveau': max(set(niveau_list), key=niveau_list.count, default=None)
    })

result_df = pd.DataFrame(results)

# Summary
total_time = (time.time() - start_time) / 60

print("\n" + "="*60)
print("COMPLETE!")
print("="*60)
print(f"Total processing time: {total_time:.1f} minutes")
print(f"Total points processed: {len(result_df)}")

print("\nFirst few rows:")
print(result_df.head())

# Save results
print("\nSaving results...")
result_df.to_pickle(r'data\Flood\clay_risk_results.pkl')
print("Results saved to 'data\Flood\clay_risk_results.pkl'")
# Out:
# Processing 26943 points with buffer_distance=1m...
#
# First point found 0 candidates
# Point 100/26943 (0.4%) | Rate: 923.75 pts/sec | Elapsed: 0.1s | Est. remaining: 0.5min
# Point 200/26943 (0.7%) | Rate: 1033.26 pts/sec | Elapsed: 0.2s | Est. remaining: 0.4min
# Point 300/26943 (1.1%) | Rate: 1017.27 pts/sec | Elapsed: 0.3s | Est. remaining: 0.4min
# Point 400/26943 (1.5%) | Rate: 805.86 pts/sec | Elapsed: 0.5s | Est. remaining: 0.5min
# Point 500/26943 (1.9%) | Rate: 670.55 pts/sec | Elapsed: 0.7s | Est. remaining: 0.7min
# Point 600/26943 (2.2%) | Rate: 600.61 pts/sec | Elapsed: 1.0s | Est. remaining: 0.7min
# Point 700/26943 (2.6%) | Rate: 552.66 pts/sec | Elapsed: 1.3s | Est. remaining: 0.8min
# Point 800/26943 (3.0%) | Rate: 548.27 pts/sec | Elapsed: 1.5s | Est. remaining: 0.8min
# Point 900/26943 (3.3%) | Rate: 533.16 pts/sec | Elapsed: 1.7s | Est. remaining: 0.8min
# Point 1000/26943 (3.7%) | Rate: 517.35 pts/sec | Elapsed: 1.9s | Est. remaining: 0.8min
# Point 1100/26943 (4.1%) | Rate: 512.72 pts/sec | Elapsed: 2.1s | Est. remaining: 0.8min
# Point 1200/26943 (4.5%) | Rate: 506.16 pts/sec | Elapsed: 2.4s | Est. remaining: 0.8min
# Point 1300/26943 (4.8%) | Rate: 499.01 pts/sec | Elapsed: 2.6s | Est. remaining: 0.9min
# Point 1400/26943 (5.2%) | Rate: 496.87 pts/sec | Elapsed: 2.8s | Est. remaining: 0.9min
# Point 1500/26943 (5.6%) | Rate: 481.98 pts/sec | Elapsed: 3.1s | Est. remaining: 0.9min
# Point 1600/26943 (5.9%) | Rate: 473.72 pts/sec | Elapsed: 3.4s | Est. remaining: 0.9min
# Point 1700/26943 (6.3%) | Rate: 468.34 pts/sec | Elapsed: 3.6s | Est. remaining: 0.9min
# Point 1800/26943 (6.7%) | Rate: 467.02 pts/sec | Elapsed: 3.9s | Est. remaining: 0.9min
# Point 1900/26943 (7.1%) | Rate: 455.92 pts/sec | Elapsed: 4.2s | Est. remaining: 0.9min
# Point 2000/26943 (7.4%) | Rate: 447.30 pts/sec | Elapsed: 4.5s | Est. remaining: 0.9min
# Point 2100/26943 (7.8%) | Rate: 441.77 pts/sec | Elapsed: 4.8s | Est. remaining: 0.9min
# Point 2200/26943 (8.2%) | Rate: 439.81 pts/sec | Elapsed: 5.0s | Est. remaining: 0.9min
# Point 2300/26943 (8.5%) | Rate: 435.08 pts/sec | Elapsed: 5.3s | Est. remaining: 0.9min
# Point 2400/26943 (8.9%) | Rate: 437.65 pts/sec | Elapsed: 5.5s | Est. remaining: 0.9min
# Point 2500/26943 (9.3%) | Rate: 433.69 pts/sec | Elapsed: 5.8s | Est. remaining: 0.9min
# Point 2600/26943 (9.7%) | Rate: 430.81 pts/sec | Elapsed: 6.0s | Est. remaining: 0.9min
# Point 2700/26943 (10.0%) | Rate: 426.45 pts/sec | Elapsed: 6.3s | Est. remaining: 0.9min
# Point 2800/26943 (10.4%) | Rate: 422.10 pts/sec | Elapsed: 6.6s | Est. remaining: 1.0min
# Point 2900/26943 (10.8%) | Rate: 421.95 pts/sec | Elapsed: 6.9s | Est. remaining: 0.9min
# Point 3000/26943 (11.1%) | Rate: 421.51 pts/sec | Elapsed: 7.1s | Est. remaining: 0.9min
# Point 3100/26943 (11.5%) | Rate: 420.48 pts/sec | Elapsed: 7.4s | Est. remaining: 0.9min
# Point 3200/26943 (11.9%) | Rate: 420.28 pts/sec | Elapsed: 7.6s | Est. remaining: 0.9min
# Point 3300/26943 (12.2%) | Rate: 419.30 pts/sec | Elapsed: 7.9s | Est. remaining: 0.9min
# Point 3400/26943 (12.6%) | Rate: 419.16 pts/sec | Elapsed: 8.1s | Est. remaining: 0.9min
# Point 3500/26943 (13.0%) | Rate: 419.02 pts/sec | Elapsed: 8.4s | Est. remaining: 0.9min
# Point 3600/26943 (13.4%) | Rate: 414.60 pts/sec | Elapsed: 8.7s | Est. remaining: 0.9min
# Point 3700/26943 (13.7%) | Rate: 412.80 pts/sec | Elapsed: 9.0s | Est. remaining: 0.9min
# Point 3800/26943 (14.1%) | Rate: 410.36 pts/sec | Elapsed: 9.3s | Est. remaining: 0.9min
# Point 3900/26943 (14.5%) | Rate: 409.16 pts/sec | Elapsed: 9.5s | Est. remaining: 0.9min
# Point 4000/26943 (14.8%) | Rate: 408.91 pts/sec | Elapsed: 9.8s | Est. remaining: 0.9min
# Point 4100/26943 (15.2%) | Rate: 410.34 pts/sec | Elapsed: 10.0s | Est. remaining: 0.9min
# Point 4200/26943 (15.6%) | Rate: 410.60 pts/sec | Elapsed: 10.2s | Est. remaining: 0.9min
# Point 4300/26943 (16.0%) | Rate: 409.76 pts/sec | Elapsed: 10.5s | Est. remaining: 0.9min
# Point 4400/26943 (16.3%) | Rate: 407.84 pts/sec | Elapsed: 10.8s | Est. remaining: 0.9min
# Point 4500/26943 (16.7%) | Rate: 404.98 pts/sec | Elapsed: 11.1s | Est. remaining: 0.9min
# Point 4600/26943 (17.1%) | Rate: 404.91 pts/sec | Elapsed: 11.4s | Est. remaining: 0.9min
# Point 4700/26943 (17.4%) | Rate: 402.68 pts/sec | Elapsed: 11.7s | Est. remaining: 0.9min
# Point 4800/26943 (17.8%) | Rate: 401.07 pts/sec | Elapsed: 12.0s | Est. remaining: 0.9min
# Point 4900/26943 (18.2%) | Rate: 398.30 pts/sec | Elapsed: 12.3s | Est. remaining: 0.9min
# Point 5000/26943 (18.6%) | Rate: 394.25 pts/sec | Elapsed: 12.7s | Est. remaining: 0.9min
# Point 5100/26943 (18.9%) | Rate: 391.59 pts/sec | Elapsed: 13.0s | Est. remaining: 0.9min
# Point 5200/26943 (19.3%) | Rate: 390.24 pts/sec | Elapsed: 13.3s | Est. remaining: 0.9min
# Point 5300/26943 (19.7%) | Rate: 389.24 pts/sec | Elapsed: 13.6s | Est. remaining: 0.9min
# Point 5400/26943 (20.0%) | Rate: 387.50 pts/sec | Elapsed: 13.9s | Est. remaining: 0.9min
# Point 5500/26943 (20.4%) | Rate: 385.44 pts/sec | Elapsed: 14.3s | Est. remaining: 0.9min
# Point 5600/26943 (20.8%) | Rate: 382.19 pts/sec | Elapsed: 14.7s | Est. remaining: 0.9min
# Point 5700/26943 (21.2%) | Rate: 379.33 pts/sec | Elapsed: 15.0s | Est. remaining: 0.9min
# Point 5800/26943 (21.5%) | Rate: 376.76 pts/sec | Elapsed: 15.4s | Est. remaining: 0.9min
# Point 5900/26943 (21.9%) | Rate: 374.04 pts/sec | Elapsed: 15.8s | Est. remaining: 0.9min
# Point 6000/26943 (22.3%) | Rate: 372.19 pts/sec | Elapsed: 16.1s | Est. remaining: 0.9min
# Point 6100/26943 (22.6%) | Rate: 372.43 pts/sec | Elapsed: 16.4s | Est. remaining: 0.9min
# Point 6200/26943 (23.0%) | Rate: 372.46 pts/sec | Elapsed: 16.6s | Est. remaining: 0.9min
# Point 6300/26943 (23.4%) | Rate: 371.87 pts/sec | Elapsed: 16.9s | Est. remaining: 0.9min
# Point 6400/26943 (23.8%) | Rate: 370.34 pts/sec | Elapsed: 17.3s | Est. remaining: 0.9min
# Point 6500/26943 (24.1%) | Rate: 369.18 pts/sec | Elapsed: 17.6s | Est. remaining: 0.9min
# Point 6600/26943 (24.5%) | Rate: 367.77 pts/sec | Elapsed: 17.9s | Est. remaining: 0.9min
# Point 6700/26943 (24.9%) | Rate: 365.38 pts/sec | Elapsed: 18.3s | Est. remaining: 0.9min
# Point 6800/26943 (25.2%) | Rate: 364.99 pts/sec | Elapsed: 18.6s | Est. remaining: 0.9min
# Point 6900/26943 (25.6%) | Rate: 363.83 pts/sec | Elapsed: 19.0s | Est. remaining: 0.9min
# Point 7000/26943 (26.0%) | Rate: 364.32 pts/sec | Elapsed: 19.2s | Est. remaining: 0.9min
# Point 7100/26943 (26.4%) | Rate: 363.84 pts/sec | Elapsed: 19.5s | Est. remaining: 0.9min
# Point 7200/26943 (26.7%) | Rate: 364.79 pts/sec | Elapsed: 19.7s | Est. remaining: 0.9min
# Point 7300/26943 (27.1%) | Rate: 365.37 pts/sec | Elapsed: 20.0s | Est. remaining: 0.9min
# Point 7400/26943 (27.5%) | Rate: 365.24 pts/sec | Elapsed: 20.3s | Est. remaining: 0.9min
# Point 7500/26943 (27.8%) | Rate: 364.86 pts/sec | Elapsed: 20.6s | Est. remaining: 0.9min
# Point 7600/26943 (28.2%) | Rate: 364.56 pts/sec | Elapsed: 20.8s | Est. remaining: 0.9min
# Point 7700/26943 (28.6%) | Rate: 364.23 pts/sec | Elapsed: 21.1s | Est. remaining: 0.9min
# Point 7800/26943 (29.0%) | Rate: 364.34 pts/sec | Elapsed: 21.4s | Est. remaining: 0.9min
# Point 7900/26943 (29.3%) | Rate: 363.97 pts/sec | Elapsed: 21.7s | Est. remaining: 0.9min
# Point 8000/26943 (29.7%) | Rate: 363.99 pts/sec | Elapsed: 22.0s | Est. remaining: 0.9min
# Point 8100/26943 (30.1%) | Rate: 363.23 pts/sec | Elapsed: 22.3s | Est. remaining: 0.9min
# Point 8200/26943 (30.4%) | Rate: 361.65 pts/sec | Elapsed: 22.7s | Est. remaining: 0.9min
# Point 8300/26943 (30.8%) | Rate: 360.16 pts/sec | Elapsed: 23.0s | Est. remaining: 0.9min
# Point 8400/26943 (31.2%) | Rate: 359.46 pts/sec | Elapsed: 23.4s | Est. remaining: 0.9min
# Point 8500/26943 (31.5%) | Rate: 358.43 pts/sec | Elapsed: 23.7s | Est. remaining: 0.9min
# Point 8600/26943 (31.9%) | Rate: 357.68 pts/sec | Elapsed: 24.0s | Est. remaining: 0.9min
# Point 8700/26943 (32.3%) | Rate: 356.96 pts/sec | Elapsed: 24.4s | Est. remaining: 0.9min
# Point 8800/26943 (32.7%) | Rate: 355.48 pts/sec | Elapsed: 24.8s | Est. remaining: 0.9min
# Point 8900/26943 (33.0%) | Rate: 355.59 pts/sec | Elapsed: 25.0s | Est. remaining: 0.8min
# Point 9000/26943 (33.4%) | Rate: 356.85 pts/sec | Elapsed: 25.2s | Est. remaining: 0.8min
# Point 9100/26943 (33.8%) | Rate: 359.39 pts/sec | Elapsed: 25.3s | Est. remaining: 0.8min
# Point 9200/26943 (34.1%) | Rate: 362.32 pts/sec | Elapsed: 25.4s | Est. remaining: 0.8min
# Point 9300/26943 (34.5%) | Rate: 364.23 pts/sec | Elapsed: 25.5s | Est. remaining: 0.8min
# Point 9400/26943 (34.9%) | Rate: 365.15 pts/sec | Elapsed: 25.7s | Est. remaining: 0.8min
# Point 9500/26943 (35.3%) | Rate: 365.20 pts/sec | Elapsed: 26.0s | Est. remaining: 0.8min
# Point 9600/26943 (35.6%) | Rate: 365.59 pts/sec | Elapsed: 26.3s | Est. remaining: 0.8min
# Point 9700/26943 (36.0%) | Rate: 365.84 pts/sec | Elapsed: 26.5s | Est. remaining: 0.8min
# Point 9800/26943 (36.4%) | Rate: 366.78 pts/sec | Elapsed: 26.7s | Est. remaining: 0.8min
# Point 9900/26943 (36.7%) | Rate: 367.04 pts/sec | Elapsed: 27.0s | Est. remaining: 0.8min
# Point 10000/26943 (37.1%) | Rate: 367.73 pts/sec | Elapsed: 27.2s | Est. remaining: 0.8min
# Point 10100/26943 (37.5%) | Rate: 366.81 pts/sec | Elapsed: 27.5s | Est. remaining: 0.8min
# Point 10200/26943 (37.9%) | Rate: 367.05 pts/sec | Elapsed: 27.8s | Est. remaining: 0.8min
# Point 10300/26943 (38.2%) | Rate: 367.70 pts/sec | Elapsed: 28.0s | Est. remaining: 0.8min
# Point 10400/26943 (38.6%) | Rate: 368.49 pts/sec | Elapsed: 28.2s | Est. remaining: 0.7min
# Point 10500/26943 (39.0%) | Rate: 368.94 pts/sec | Elapsed: 28.5s | Est. remaining: 0.7min
# Point 10600/26943 (39.3%) | Rate: 368.88 pts/sec | Elapsed: 28.7s | Est. remaining: 0.7min
# Point 10700/26943 (39.7%) | Rate: 369.67 pts/sec | Elapsed: 28.9s | Est. remaining: 0.7min
# Point 10800/26943 (40.1%) | Rate: 369.32 pts/sec | Elapsed: 29.2s | Est. remaining: 0.7min
# Point 10900/26943 (40.5%) | Rate: 368.45 pts/sec | Elapsed: 29.6s | Est. remaining: 0.7min
# Point 11000/26943 (40.8%) | Rate: 367.20 pts/sec | Elapsed: 30.0s | Est. remaining: 0.7min
# Point 11100/26943 (41.2%) | Rate: 366.70 pts/sec | Elapsed: 30.3s | Est. remaining: 0.7min
# Point 11200/26943 (41.6%) | Rate: 365.51 pts/sec | Elapsed: 30.6s | Est. remaining: 0.7min
# Point 11300/26943 (41.9%) | Rate: 364.83 pts/sec | Elapsed: 31.0s | Est. remaining: 0.7min
# Point 11400/26943 (42.3%) | Rate: 365.50 pts/sec | Elapsed: 31.2s | Est. remaining: 0.7min
# Point 11500/26943 (42.7%) | Rate: 364.83 pts/sec | Elapsed: 31.5s | Est. remaining: 0.7min
# Point 11600/26943 (43.1%) | Rate: 363.14 pts/sec | Elapsed: 31.9s | Est. remaining: 0.7min
# Point 11700/26943 (43.4%) | Rate: 362.57 pts/sec | Elapsed: 32.3s | Est. remaining: 0.7min
# Point 11800/26943 (43.8%) | Rate: 361.86 pts/sec | Elapsed: 32.6s | Est. remaining: 0.7min
# Point 11900/26943 (44.2%) | Rate: 362.06 pts/sec | Elapsed: 32.9s | Est. remaining: 0.7min
# Point 12000/26943 (44.5%) | Rate: 361.72 pts/sec | Elapsed: 33.2s | Est. remaining: 0.7min
# Point 12100/26943 (44.9%) | Rate: 361.67 pts/sec | Elapsed: 33.5s | Est. remaining: 0.7min
# Point 12200/26943 (45.3%) | Rate: 361.33 pts/sec | Elapsed: 33.8s | Est. remaining: 0.7min
# Point 12300/26943 (45.7%) | Rate: 360.98 pts/sec | Elapsed: 34.1s | Est. remaining: 0.7min
# Point 12400/26943 (46.0%) | Rate: 360.46 pts/sec | Elapsed: 34.4s | Est. remaining: 0.7min
# Point 12500/26943 (46.4%) | Rate: 360.48 pts/sec | Elapsed: 34.7s | Est. remaining: 0.7min
# Point 12600/26943 (46.8%) | Rate: 360.67 pts/sec | Elapsed: 34.9s | Est. remaining: 0.7min
# Point 12700/26943 (47.1%) | Rate: 360.38 pts/sec | Elapsed: 35.2s | Est. remaining: 0.7min
# Point 12800/26943 (47.5%) | Rate: 360.11 pts/sec | Elapsed: 35.5s | Est. remaining: 0.7min
# Point 12900/26943 (47.9%) | Rate: 360.48 pts/sec | Elapsed: 35.8s | Est. remaining: 0.6min
# Point 13000/26943 (48.3%) | Rate: 361.06 pts/sec | Elapsed: 36.0s | Est. remaining: 0.6min
# Point 13100/26943 (48.6%) | Rate: 361.72 pts/sec | Elapsed: 36.2s | Est. remaining: 0.6min
# Point 13200/26943 (49.0%) | Rate: 362.06 pts/sec | Elapsed: 36.5s | Est. remaining: 0.6min
# Point 13300/26943 (49.4%) | Rate: 362.06 pts/sec | Elapsed: 36.7s | Est. remaining: 0.6min
# Point 13400/26943 (49.7%) | Rate: 361.89 pts/sec | Elapsed: 37.0s | Est. remaining: 0.6min
# Point 13500/26943 (50.1%) | Rate: 362.28 pts/sec | Elapsed: 37.3s | Est. remaining: 0.6min
# Point 13600/26943 (50.5%) | Rate: 362.35 pts/sec | Elapsed: 37.5s | Est. remaining: 0.6min
# Point 13700/26943 (50.8%) | Rate: 362.24 pts/sec | Elapsed: 37.8s | Est. remaining: 0.6min
# Point 13800/26943 (51.2%) | Rate: 362.14 pts/sec | Elapsed: 38.1s | Est. remaining: 0.6min
# Point 13900/26943 (51.6%) | Rate: 361.39 pts/sec | Elapsed: 38.5s | Est. remaining: 0.6min
# Point 14000/26943 (52.0%) | Rate: 360.05 pts/sec | Elapsed: 38.9s | Est. remaining: 0.6min
# Point 14100/26943 (52.3%) | Rate: 359.59 pts/sec | Elapsed: 39.2s | Est. remaining: 0.6min
# Point 14200/26943 (52.7%) | Rate: 359.35 pts/sec | Elapsed: 39.5s | Est. remaining: 0.6min
# Point 14300/26943 (53.1%) | Rate: 358.96 pts/sec | Elapsed: 39.8s | Est. remaining: 0.6min
# Point 14400/26943 (53.4%) | Rate: 358.71 pts/sec | Elapsed: 40.1s | Est. remaining: 0.6min
# Point 14500/26943 (53.8%) | Rate: 358.19 pts/sec | Elapsed: 40.5s | Est. remaining: 0.6min
# Point 14600/26943 (54.2%) | Rate: 357.40 pts/sec | Elapsed: 40.9s | Est. remaining: 0.6min
# Point 14700/26943 (54.6%) | Rate: 356.32 pts/sec | Elapsed: 41.3s | Est. remaining: 0.6min
# Point 14800/26943 (54.9%) | Rate: 355.41 pts/sec | Elapsed: 41.6s | Est. remaining: 0.6min
# Point 14900/26943 (55.3%) | Rate: 354.60 pts/sec | Elapsed: 42.0s | Est. remaining: 0.6min
# Point 15000/26943 (55.7%) | Rate: 354.02 pts/sec | Elapsed: 42.4s | Est. remaining: 0.6min
# Point 15100/26943 (56.0%) | Rate: 353.92 pts/sec | Elapsed: 42.7s | Est. remaining: 0.6min
# Point 15200/26943 (56.4%) | Rate: 353.34 pts/sec | Elapsed: 43.0s | Est. remaining: 0.6min
# Point 15300/26943 (56.8%) | Rate: 352.72 pts/sec | Elapsed: 43.4s | Est. remaining: 0.6min
# Point 15400/26943 (57.2%) | Rate: 352.48 pts/sec | Elapsed: 43.7s | Est. remaining: 0.5min
# Point 15500/26943 (57.5%) | Rate: 352.28 pts/sec | Elapsed: 44.0s | Est. remaining: 0.5min
# Point 15600/26943 (57.9%) | Rate: 351.98 pts/sec | Elapsed: 44.3s | Est. remaining: 0.5min
# Point 15700/26943 (58.3%) | Rate: 351.56 pts/sec | Elapsed: 44.7s | Est. remaining: 0.5min
# Point 15800/26943 (58.6%) | Rate: 351.42 pts/sec | Elapsed: 45.0s | Est. remaining: 0.5min
# Point 15900/26943 (59.0%) | Rate: 351.48 pts/sec | Elapsed: 45.2s | Est. remaining: 0.5min
# Point 16000/26943 (59.4%) | Rate: 351.51 pts/sec | Elapsed: 45.5s | Est. remaining: 0.5min
# Point 16100/26943 (59.8%) | Rate: 351.62 pts/sec | Elapsed: 45.8s | Est. remaining: 0.5min
# Point 16200/26943 (60.1%) | Rate: 352.05 pts/sec | Elapsed: 46.0s | Est. remaining: 0.5min
# Point 16300/26943 (60.5%) | Rate: 352.45 pts/sec | Elapsed: 46.2s | Est. remaining: 0.5min
# Point 16400/26943 (60.9%) | Rate: 352.53 pts/sec | Elapsed: 46.5s | Est. remaining: 0.5min
# Point 16500/26943 (61.2%) | Rate: 352.37 pts/sec | Elapsed: 46.8s | Est. remaining: 0.5min
# Point 16600/26943 (61.6%) | Rate: 352.48 pts/sec | Elapsed: 47.1s | Est. remaining: 0.5min
# Point 16700/26943 (62.0%) | Rate: 352.30 pts/sec | Elapsed: 47.4s | Est. remaining: 0.5min
# Point 16800/26943 (62.4%) | Rate: 352.37 pts/sec | Elapsed: 47.7s | Est. remaining: 0.5min
# Point 16900/26943 (62.7%) | Rate: 352.34 pts/sec | Elapsed: 48.0s | Est. remaining: 0.5min
# Point 17000/26943 (63.1%) | Rate: 352.09 pts/sec | Elapsed: 48.3s | Est. remaining: 0.5min
# Point 17100/26943 (63.5%) | Rate: 351.89 pts/sec | Elapsed: 48.6s | Est. remaining: 0.5min
# Point 17200/26943 (63.8%) | Rate: 351.33 pts/sec | Elapsed: 49.0s | Est. remaining: 0.5min
# Point 17300/26943 (64.2%) | Rate: 350.84 pts/sec | Elapsed: 49.3s | Est. remaining: 0.5min
# Point 17400/26943 (64.6%) | Rate: 350.47 pts/sec | Elapsed: 49.6s | Est. remaining: 0.5min
# Point 17500/26943 (65.0%) | Rate: 350.08 pts/sec | Elapsed: 50.0s | Est. remaining: 0.4min
# Point 17600/26943 (65.3%) | Rate: 349.90 pts/sec | Elapsed: 50.3s | Est. remaining: 0.4min
# Point 17700/26943 (65.7%) | Rate: 349.61 pts/sec | Elapsed: 50.6s | Est. remaining: 0.4min
# Point 17800/26943 (66.1%) | Rate: 348.99 pts/sec | Elapsed: 51.0s | Est. remaining: 0.4min
# Point 17900/26943 (66.4%) | Rate: 349.41 pts/sec | Elapsed: 51.2s | Est. remaining: 0.4min
# Point 18000/26943 (66.8%) | Rate: 350.38 pts/sec | Elapsed: 51.4s | Est. remaining: 0.4min
# Point 18100/26943 (67.2%) | Rate: 351.67 pts/sec | Elapsed: 51.5s | Est. remaining: 0.4min
# Point 18200/26943 (67.6%) | Rate: 353.07 pts/sec | Elapsed: 51.5s | Est. remaining: 0.4min
# Point 18300/26943 (67.9%) | Rate: 354.06 pts/sec | Elapsed: 51.7s | Est. remaining: 0.4min
# Point 18400/26943 (68.3%) | Rate: 354.53 pts/sec | Elapsed: 51.9s | Est. remaining: 0.4min
# Point 18500/26943 (68.7%) | Rate: 354.72 pts/sec | Elapsed: 52.2s | Est. remaining: 0.4min
# Point 18600/26943 (69.0%) | Rate: 354.83 pts/sec | Elapsed: 52.4s | Est. remaining: 0.4min
# Point 18700/26943 (69.4%) | Rate: 355.41 pts/sec | Elapsed: 52.6s | Est. remaining: 0.4min
# Point 18800/26943 (69.8%) | Rate: 355.79 pts/sec | Elapsed: 52.8s | Est. remaining: 0.4min
# Point 18900/26943 (70.1%) | Rate: 356.00 pts/sec | Elapsed: 53.1s | Est. remaining: 0.4min
# Point 19000/26943 (70.5%) | Rate: 356.44 pts/sec | Elapsed: 53.3s | Est. remaining: 0.4min
# Point 19100/26943 (70.9%) | Rate: 356.92 pts/sec | Elapsed: 53.5s | Est. remaining: 0.4min
# Point 19200/26943 (71.3%) | Rate: 357.27 pts/sec | Elapsed: 53.7s | Est. remaining: 0.4min
# Point 19300/26943 (71.6%) | Rate: 357.73 pts/sec | Elapsed: 54.0s | Est. remaining: 0.4min
# Point 19400/26943 (72.0%) | Rate: 358.11 pts/sec | Elapsed: 54.2s | Est. remaining: 0.4min
# Point 19500/26943 (72.4%) | Rate: 358.42 pts/sec | Elapsed: 54.4s | Est. remaining: 0.3min
# Point 19600/26943 (72.7%) | Rate: 358.57 pts/sec | Elapsed: 54.7s | Est. remaining: 0.3min
# Point 19700/26943 (73.1%) | Rate: 359.16 pts/sec | Elapsed: 54.9s | Est. remaining: 0.3min
# Point 19800/26943 (73.5%) | Rate: 359.46 pts/sec | Elapsed: 55.1s | Est. remaining: 0.3min
# Point 19900/26943 (73.9%) | Rate: 359.37 pts/sec | Elapsed: 55.4s | Est. remaining: 0.3min
# Point 20000/26943 (74.2%) | Rate: 359.53 pts/sec | Elapsed: 55.6s | Est. remaining: 0.3min
# Point 20100/26943 (74.6%) | Rate: 359.46 pts/sec | Elapsed: 55.9s | Est. remaining: 0.3min
# Point 20200/26943 (75.0%) | Rate: 359.64 pts/sec | Elapsed: 56.2s | Est. remaining: 0.3min
# Point 20300/26943 (75.3%) | Rate: 359.94 pts/sec | Elapsed: 56.4s | Est. remaining: 0.3min
# Point 20400/26943 (75.7%) | Rate: 360.51 pts/sec | Elapsed: 56.6s | Est. remaining: 0.3min
# Point 20500/26943 (76.1%) | Rate: 360.14 pts/sec | Elapsed: 56.9s | Est. remaining: 0.3min
# Point 20600/26943 (76.5%) | Rate: 360.20 pts/sec | Elapsed: 57.2s | Est. remaining: 0.3min
# Point 20700/26943 (76.8%) | Rate: 360.34 pts/sec | Elapsed: 57.4s | Est. remaining: 0.3min
# Point 20800/26943 (77.2%) | Rate: 360.31 pts/sec | Elapsed: 57.7s | Est. remaining: 0.3min
# Point 20900/26943 (77.6%) | Rate: 360.40 pts/sec | Elapsed: 58.0s | Est. remaining: 0.3min
# Point 21000/26943 (77.9%) | Rate: 360.66 pts/sec | Elapsed: 58.2s | Est. remaining: 0.3min
# Point 21100/26943 (78.3%) | Rate: 361.06 pts/sec | Elapsed: 58.4s | Est. remaining: 0.3min
# Point 21200/26943 (78.7%) | Rate: 361.28 pts/sec | Elapsed: 58.7s | Est. remaining: 0.3min
# Point 21300/26943 (79.1%) | Rate: 361.49 pts/sec | Elapsed: 58.9s | Est. remaining: 0.3min
# Point 21400/26943 (79.4%) | Rate: 361.40 pts/sec | Elapsed: 59.2s | Est. remaining: 0.3min
# Point 21500/26943 (79.8%) | Rate: 361.71 pts/sec | Elapsed: 59.4s | Est. remaining: 0.3min
# Point 21600/26943 (80.2%) | Rate: 361.76 pts/sec | Elapsed: 59.7s | Est. remaining: 0.2min
# Point 21700/26943 (80.5%) | Rate: 361.40 pts/sec | Elapsed: 60.0s | Est. remaining: 0.2min
# Point 21800/26943 (80.9%) | Rate: 361.38 pts/sec | Elapsed: 60.3s | Est. remaining: 0.2min
# Point 21900/26943 (81.3%) | Rate: 361.60 pts/sec | Elapsed: 60.6s | Est. remaining: 0.2min
# Point 22000/26943 (81.7%) | Rate: 361.87 pts/sec | Elapsed: 60.8s | Est. remaining: 0.2min
# Point 22100/26943 (82.0%) | Rate: 362.14 pts/sec | Elapsed: 61.0s | Est. remaining: 0.2min
# Point 22200/26943 (82.4%) | Rate: 362.28 pts/sec | Elapsed: 61.3s | Est. remaining: 0.2min
# Point 22300/26943 (82.8%) | Rate: 362.22 pts/sec | Elapsed: 61.6s | Est. remaining: 0.2min
# Point 22400/26943 (83.1%) | Rate: 362.26 pts/sec | Elapsed: 61.8s | Est. remaining: 0.2min
# Point 22500/26943 (83.5%) | Rate: 362.29 pts/sec | Elapsed: 62.1s | Est. remaining: 0.2min
# Point 22600/26943 (83.9%) | Rate: 362.34 pts/sec | Elapsed: 62.4s | Est. remaining: 0.2min
# Point 22700/26943 (84.3%) | Rate: 362.36 pts/sec | Elapsed: 62.6s | Est. remaining: 0.2min
# Point 22800/26943 (84.6%) | Rate: 362.27 pts/sec | Elapsed: 62.9s | Est. remaining: 0.2min
# Point 22900/26943 (85.0%) | Rate: 361.96 pts/sec | Elapsed: 63.3s | Est. remaining: 0.2min
# Point 23000/26943 (85.4%) | Rate: 361.48 pts/sec | Elapsed: 63.6s | Est. remaining: 0.2min
# Point 23100/26943 (85.7%) | Rate: 361.34 pts/sec | Elapsed: 63.9s | Est. remaining: 0.2min
# Point 23200/26943 (86.1%) | Rate: 361.21 pts/sec | Elapsed: 64.2s | Est. remaining: 0.2min
# Point 23300/26943 (86.5%) | Rate: 360.88 pts/sec | Elapsed: 64.6s | Est. remaining: 0.2min
# Point 23400/26943 (86.9%) | Rate: 360.70 pts/sec | Elapsed: 64.9s | Est. remaining: 0.2min
# Point 23500/26943 (87.2%) | Rate: 360.21 pts/sec | Elapsed: 65.2s | Est. remaining: 0.2min
# Point 23600/26943 (87.6%) | Rate: 359.43 pts/sec | Elapsed: 65.7s | Est. remaining: 0.2min
# Point 23700/26943 (88.0%) | Rate: 359.00 pts/sec | Elapsed: 66.0s | Est. remaining: 0.2min
# Point 23800/26943 (88.3%) | Rate: 358.78 pts/sec | Elapsed: 66.3s | Est. remaining: 0.1min
# Point 23900/26943 (88.7%) | Rate: 358.68 pts/sec | Elapsed: 66.6s | Est. remaining: 0.1min
# Point 24000/26943 (89.1%) | Rate: 358.61 pts/sec | Elapsed: 66.9s | Est. remaining: 0.1min
# Point 24100/26943 (89.4%) | Rate: 358.86 pts/sec | Elapsed: 67.2s | Est. remaining: 0.1min
# Point 24200/26943 (89.8%) | Rate: 358.69 pts/sec | Elapsed: 67.5s | Est. remaining: 0.1min
# Point 24300/26943 (90.2%) | Rate: 358.47 pts/sec | Elapsed: 67.8s | Est. remaining: 0.1min
# Point 24400/26943 (90.6%) | Rate: 358.45 pts/sec | Elapsed: 68.1s | Est. remaining: 0.1min
# Point 24500/26943 (90.9%) | Rate: 358.25 pts/sec | Elapsed: 68.4s | Est. remaining: 0.1min
# Point 24600/26943 (91.3%) | Rate: 358.01 pts/sec | Elapsed: 68.7s | Est. remaining: 0.1min
# Point 24700/26943 (91.7%) | Rate: 357.70 pts/sec | Elapsed: 69.1s | Est. remaining: 0.1min
# Point 24800/26943 (92.0%) | Rate: 357.48 pts/sec | Elapsed: 69.4s | Est. remaining: 0.1min
# Point 24900/26943 (92.4%) | Rate: 357.41 pts/sec | Elapsed: 69.7s | Est. remaining: 0.1min
# Point 25000/26943 (92.8%) | Rate: 357.48 pts/sec | Elapsed: 69.9s | Est. remaining: 0.1min
# Point 25100/26943 (93.2%) | Rate: 357.58 pts/sec | Elapsed: 70.2s | Est. remaining: 0.1min
# Point 25200/26943 (93.5%) | Rate: 357.85 pts/sec | Elapsed: 70.4s | Est. remaining: 0.1min
# Point 25300/26943 (93.9%) | Rate: 358.18 pts/sec | Elapsed: 70.6s | Est. remaining: 0.1min
# Point 25400/26943 (94.3%) | Rate: 358.01 pts/sec | Elapsed: 70.9s | Est. remaining: 0.1min
# Point 25500/26943 (94.6%) | Rate: 357.74 pts/sec | Elapsed: 71.3s | Est. remaining: 0.1min
# Point 25600/26943 (95.0%) | Rate: 357.68 pts/sec | Elapsed: 71.6s | Est. remaining: 0.1min
# Point 25700/26943 (95.4%) | Rate: 357.71 pts/sec | Elapsed: 71.8s | Est. remaining: 0.1min
# Point 25800/26943 (95.8%) | Rate: 357.73 pts/sec | Elapsed: 72.1s | Est. remaining: 0.1min
# Point 25900/26943 (96.1%) | Rate: 357.55 pts/sec | Elapsed: 72.4s | Est. remaining: 0.0min
# Point 26000/26943 (96.5%) | Rate: 357.43 pts/sec | Elapsed: 72.7s | Est. remaining: 0.0min
# Point 26100/26943 (96.9%) | Rate: 357.57 pts/sec | Elapsed: 73.0s | Est. remaining: 0.0min
# Point 26200/26943 (97.2%) | Rate: 357.22 pts/sec | Elapsed: 73.3s | Est. remaining: 0.0min
# Point 26300/26943 (97.6%) | Rate: 356.67 pts/sec | Elapsed: 73.7s | Est. remaining: 0.0min
# Point 26400/26943 (98.0%) | Rate: 356.61 pts/sec | Elapsed: 74.0s | Est. remaining: 0.0min
# Point 26500/26943 (98.4%) | Rate: 356.22 pts/sec | Elapsed: 74.4s | Est. remaining: 0.0min
# Point 26600/26943 (98.7%) | Rate: 356.11 pts/sec | Elapsed: 74.7s | Est. remaining: 0.0min
# Point 26700/26943 (99.1%) | Rate: 355.78 pts/sec | Elapsed: 75.0s | Est. remaining: 0.0min
# Point 26800/26943 (99.5%) | Rate: 355.38 pts/sec | Elapsed: 75.4s | Est. remaining: 0.0min
# Point 26900/26943 (99.8%) | Rate: 355.71 pts/sec | Elapsed: 75.6s | Est. remaining: 0.0min
#
# ============================================================
# COMPLETE!
# ============================================================
# Total processing time: 1.3 minutes
# Total points processed: 26943
#
# First few rows:
#    longitude  latitude    alea  niveau
# 0     9.1495   41.3373    None     NaN
# 1     9.0628   41.4149    None     NaN
# 2     9.1577   41.4087  Faible     1.0
# 3     9.2527   41.4025    None     NaN
# 4     8.8808   41.4985    None     NaN
#
# Saving results...
# Results saved to 'data\Flood\clay_risk_results.pkl'

# %% [markdown]
# # Save and export to csv

# %%
result_df.to_csv(r'data\Flood\clay_risk_results.csv')
print("Results saved to 'data\Flood\clay_risk_results.csv'")
# Out:
# Results saved to 'data\Flood\clay_risk_results.csv'

# %% [markdown]
# L'aléa d'inondation est composé de 4 sous aléa, par la suite nous regroupons ces aléa par probabilité d'occurences.
